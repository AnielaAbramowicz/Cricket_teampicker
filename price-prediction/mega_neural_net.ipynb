# %% [markdown]
# # Price Prediction Neural Network
#
# The notebook contains the code used to create and train the neural network which is used to predict prices for IPL auctions. The notebook also contains the code used to prepare data to be used as inputs to the network. The amount of code required to prepare the data can probably be significantly reduced/made more concise but I was lazy and copy/pasted a bunch of it, just changing variable names for each auction year.

# %%
# Imports and stuff

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

sns.set_style('whitegrid')
warnings.filterwarnings('ignore')

# %% [markdown]
# # Preparing the data

# %% [markdown]
# ## 2018

# %% [markdown]
# The following stuff just loads in all the 2018 data and puts it into one dataframe.

# %%
auction_2018 = pd.read_csv('data/2018/ipl_auction_2018.csv')
auction_2018.set_index('Player', inplace=True)

# The following stats are calculates across two year intervals
# so, ipl_stats_1 contains stats calculated across the 2016 and 2017 seasons
# and ipl_stats_2 contains contains stats calculated across the 2008 to 2017 seasons
# For the it20 stats, the same follows, except the time intervals
# end the day before the auction of the 2018 ipl season

ipl_stats_1 = pd.read_csv('data/2018/ipl_stats_2016_2017.csv')
ipl_stats_2 = pd.read_csv('data/2018/ipl_stats_2008_2017.csv')
it20_stats_1 = pd.read_csv('data/2018/it20_stats_2016_2017.csv')
it20_stats_2 = pd.read_csv('data/2018/it20_stats_2005_2017.csv')

# Index by player name
ipl_stats_1.set_index('Player', inplace=True)
ipl_stats_2.set_index('Player', inplace=True)
it20_stats_1.set_index('Player', inplace=True)
it20_stats_2.set_index('Player', inplace=True)

# Drop played for country column if it exists
if 'Played For Country' in ipl_stats_1.columns:
    ipl_stats_1.drop('Played For Country', axis=1, inplace=True)
if 'Played For Country' in ipl_stats_2.columns:
    ipl_stats_2.drop('Played For Country', axis=1, inplace=True)
if 'Played For Country' in it20_stats_1.columns:
    it20_stats_1.drop('Played For Country', axis=1, inplace=True)
if 'Played For Country' in it20_stats_2.columns:
    it20_stats_2.drop('Played For Country', axis=1, inplace=True)

# Renaming the columns to make them unique
ipl_stats_1.columns = ['ipl 1 ' + col for col in ipl_stats_1.columns]
ipl_stats_2.columns = ['ipl 2 ' + col for col in ipl_stats_2.columns]
it20_stats_1.columns = ['it20 1 ' + col for col in it20_stats_1.columns]
it20_stats_2.columns = ['it20 2 ' + col for col in it20_stats_2.columns]

# Merging the dataframes
data_2018 = pd.concat([auction_2018, ipl_stats_1, ipl_stats_2, it20_stats_1, it20_stats_2], axis=1, sort=False)


print(data_2018.columns)
data_2018.head()
# Out:
# Index(['Role', 'Amount', 'Team', 'Year', 'Player Origin', 'dob',
#        'Played For Country', 'ipl 1 runs', 'ipl 1 balls', 'ipl 1 4s',
#        'ipl 1 6s', 'ipl 1 batting SR', 'ipl 1 batting average',
#        'ipl 1 times dismissed', 'ipl 1 balls bowled', 'ipl 1 runs conceded',
#        'ipl 1 wickets', 'ipl 1 economy', 'ipl 1 bowling average',
#        'ipl 1 bowling SR', 'ipl 1 overs bowled', 'ipl 1 wides',
#        'ipl 1 noballs', 'ipl 2 runs', 'ipl 2 balls', 'ipl 2 4s', 'ipl 2 6s',
#        'ipl 2 batting SR', 'ipl 2 batting average', 'ipl 2 times dismissed',
#        'ipl 2 balls bowled', 'ipl 2 runs conceded', 'ipl 2 wickets',
#        'ipl 2 economy', 'ipl 2 bowling average', 'ipl 2 bowling SR',
#        'ipl 2 overs bowled', 'ipl 2 wides', 'ipl 2 noballs', 'it20 1 runs',
#        'it20 1 balls', 'it20 1 4s', 'it20 1 6s', 'it20 1 batting SR',
#        'it20 1 batting average', 'it20 1 times dismissed',
#        'it20 1 balls bowled', 'it20 1 runs conceded', 'it20 1 wickets',
#        'it20 1 economy', 'it20 1 bowling average', 'it20 1 bowling SR',
#        'it20 1 overs bowled', 'it20 1 wides', 'it20 1 noballs', 'it20 2 runs',
#        'it20 2 balls', 'it20 2 4s', 'it20 2 6s', 'it20 2 batting SR',
#        'it20 2 batting average', 'it20 2 times dismissed',
#        'it20 2 balls bowled', 'it20 2 runs conceded', 'it20 2 wickets',
#        'it20 2 economy', 'it20 2 bowling average', 'it20 2 bowling SR',
#        'it20 2 overs bowled', 'it20 2 wides', 'it20 2 noballs'],
#       dtype='object')
#                            Role    Amount              Team    Year  \
# Player
# Aaron Finch             Batsman  62000000   Kings XI Punjab  2018.0
# Abhishek Sharma     All-Rounder   5500000  Delhi Daredevils  2018.0
# Aditya Tare       Wicket Keeper   2000000    Mumbai Indians  2018.0
# Ajinkya Rahane          Batsman  40000000  Rajasthan Royals  2018.0
# Akila Dhananjaya         Bowler   5000000    Mumbai Indians  2018.0
#
#                  Player Origin         dob  Played For Country  ipl 1 runs  \
# Player
# Aaron Finch           Overseas  1986-11-17                 1.0       692.0
# Abhishek Sharma         Indian  2000-09-04                 0.0         NaN
# Aditya Tare             Indian  1987-11-07                 0.0        26.0
# Ajinkya Rahane          Indian  1988-06-06                 1.0       862.0
# Akila Dhananjaya      Overseas         NaN                 0.0         NaN
#
#                   ipl 1 balls  ipl 1 4s  ...  it20 2 times dismissed  \
# Player                                   ...
# Aaron Finch             473.0      70.0  ...                    27.0
# Abhishek Sharma           NaN       NaN  ...                     NaN
# Aditya Tare              38.0       4.0  ...                     NaN
# Ajinkya Rahane          701.0      89.0  ...                    17.0
# Akila Dhananjaya          NaN       NaN  ...                     NaN
#
#                   it20 2 balls bowled  it20 2 runs conceded  it20 2 wickets  \
# Player
# Aaron Finch                       6.0                   9.0             0.0
# Abhishek Sharma                   NaN                   NaN             NaN
# Aditya Tare                       NaN                   NaN             NaN
# Ajinkya Rahane                    0.0                   0.0             0.0
# Akila Dhananjaya                  NaN                   NaN             NaN
#
#                   it20 2 economy  it20 2 bowling average  it20 2 bowling SR  \
# Player
# Aaron Finch                  9.0                     NaN                NaN
# Abhishek Sharma              NaN                     NaN                NaN
# Aditya Tare                  NaN                     NaN                NaN
# Ajinkya Rahane               NaN                     NaN                NaN
# Akila Dhananjaya             NaN                     NaN                NaN
#
#                   it20 2 overs bowled  it20 2 wides  it20 2 noballs
# Player
# Aaron Finch                       1.0           0.0             0.0
# Abhishek Sharma                   NaN           NaN             NaN
# Aditya Tare                       NaN           NaN             NaN
# Ajinkya Rahane                    0.0           0.0             0.0
# Akila Dhananjaya                  NaN           NaN             NaN
#
# [5 rows x 71 columns]

# %%
# Now let's convert DOB to age at time of auction

auction_date = pd.to_datetime('2018-01-27')
data_2018['Age'] = (auction_date - pd.to_datetime(data_2018['dob'])).dt.days // 365

# Drop the DOB column
data_2018.drop('dob', axis=1, inplace=True)

# I'm just going to replace missing ages with the mean age (for now at least)
data_2018['Age'].fillna(data_2018['Age'].mean(), inplace=True)

print(data_2018['Age'].describe())
# Out:
# count    169.000000
# mean      26.944056
# std        4.579686
# min       17.000000
# 25%       25.000000
# 50%       26.944056
# 75%       29.000000
# max       43.000000
# Name: Age, dtype: float64

# %%
# Deal with missing values
data_2018.fillna(0, inplace=True)
data_2018.isnull().sum()
# Out:
# Role                   0
# Amount                 0
# Team                   0
# Year                   0
# Player Origin          0
#                       ..
# it20 2 bowling SR      0
# it20 2 overs bowled    0
# it20 2 wides           0
# it20 2 noballs         0
# Age                    0
# Length: 71, dtype: int64

# %%
# Drop the 'Team' column
data_2018.drop('Team', axis=1, inplace=True)

# Add dummy variables for 'Role' and 'Player Origin'
data_2018 = pd.get_dummies(data_2018, columns=['Role', 'Player Origin'])

# %% [markdown]
# *Do the same as above for the next auctions*

# %% [markdown]
# ## 2019

# %%
auction_2019 = pd.read_csv('data/2019/ipl_auction_2019.csv')
auction_2019.set_index('Player', inplace=True)

# The following stats are calculates across two year intervals
# so, ipl_stats_1 contains stats calculated across the 2016 and 2017 seasons
# and ipl_stats_2 contains stats calculated across the 2014 and 2015 seasons
# For the it20 stats, the same follows, except the two year interval\
# ends the day before the auction of the 2018 ipl season

ipl_stats_1 = pd.read_csv('data/2019/ipl_stats_2017_2018.csv')
ipl_stats_2 = pd.read_csv('data/2019/ipl_stats_2008_2018.csv')
it20_stats_1 = pd.read_csv('data/2019/it20_stats_2017_2018.csv')
it20_stats_2 = pd.read_csv('data/2019/it20_stats_2005_2018.csv')

# Index by player name
ipl_stats_1.set_index('Player', inplace=True)
ipl_stats_2.set_index('Player', inplace=True)
it20_stats_1.set_index('Player', inplace=True)
it20_stats_2.set_index('Player', inplace=True)

# Drop played for country column if it exists
if 'Played For Country' in ipl_stats_1.columns:
    ipl_stats_1.drop('Played For Country', axis=1, inplace=True)
if 'Played For Country' in ipl_stats_2.columns:
    ipl_stats_2.drop('Played For Country', axis=1, inplace=True)
if 'Played For Country' in it20_stats_1.columns:
    it20_stats_1.drop('Played For Country', axis=1, inplace=True)
if 'Played For Country' in it20_stats_2.columns:
    it20_stats_2.drop('Played For Country', axis=1, inplace=True)

# Renaming the columns to make them unique
ipl_stats_1.columns = ['ipl 1 ' + col for col in ipl_stats_1.columns]
ipl_stats_2.columns = ['ipl 2 ' + col for col in ipl_stats_2.columns]
it20_stats_1.columns = ['it20 1 ' + col for col in it20_stats_1.columns]
it20_stats_2.columns = ['it20 2 ' + col for col in it20_stats_2.columns]

# Merging the dataframes
data_2019 = pd.concat([auction_2019, ipl_stats_1, ipl_stats_2, it20_stats_1, it20_stats_2], axis=1, sort=False)

data_2019.head()
# Out:
#                            Role    Amount                         Team  \
# Player
# Agnivesh Ayachi     All-Rounder   2000000              Kings XI Punjab
# Akshdeep Nath       All-Rounder  36000000  Royal Challengers Bangalore
# Ankush Bains      Wicket Keeper   2000000               Delhi Capitals
# Anmolpreet Singh        Batsman   8000000               Mumbai Indians
# Anrich Nortje            Bowler   2000000        Kolkata Knight Riders
#
#                     Year Player Origin  Played For Country         dob  \
# Player
# Agnivesh Ayachi   2019.0        Indian                 0.0  1995-06-15
# Akshdeep Nath     2019.0        Indian                 0.0  1993-05-10
# Ankush Bains      2019.0        Indian                 0.0  1995-12-16
# Anmolpreet Singh  2019.0        Indian                 0.0  1998-03-28
# Anrich Nortje     2019.0      Overseas                 0.0  1993-11-16
#
#                   ipl 1 runs  ipl 1 balls  ipl 1 4s  ...  \
# Player                                               ...
# Agnivesh Ayachi          NaN          NaN       NaN  ...
# Akshdeep Nath            9.0         14.0       1.0  ...
# Ankush Bains             NaN          NaN       NaN  ...
# Anmolpreet Singh         NaN          NaN       NaN  ...
# Anrich Nortje            NaN          NaN       NaN  ...
#
#                   it20 2 times dismissed  it20 2 balls bowled  \
# Player
# Agnivesh Ayachi                      NaN                  NaN
# Akshdeep Nath                        NaN                  NaN
# Ankush Bains                         NaN                  NaN
# Anmolpreet Singh                     NaN                  NaN
# Anrich Nortje                        NaN                  NaN
#
#                   it20 2 runs conceded  it20 2 wickets  it20 2 economy  \
# Player
# Agnivesh Ayachi                    NaN             NaN             NaN
# Akshdeep Nath                      NaN             NaN             NaN
# Ankush Bains                       NaN             NaN             NaN
# Anmolpreet Singh                   NaN             NaN             NaN
# Anrich Nortje                      NaN             NaN             NaN
#
#                   it20 2 bowling average  it20 2 bowling SR  \
# Player
# Agnivesh Ayachi                      NaN                NaN
# Akshdeep Nath                        NaN                NaN
# Ankush Bains                         NaN                NaN
# Anmolpreet Singh                     NaN                NaN
# Anrich Nortje                        NaN                NaN
#
#                   it20 2 overs bowled  it20 2 wides  it20 2 noballs
# Player
# Agnivesh Ayachi                   NaN           NaN             NaN
# Akshdeep Nath                     NaN           NaN             NaN
# Ankush Bains                      NaN           NaN             NaN
# Anmolpreet Singh                  NaN           NaN             NaN
# Anrich Nortje                     NaN           NaN             NaN
#
# [5 rows x 71 columns]

# %%
# Now let's convert DOB to age at time of auction

auction_date = pd.to_datetime('2018-12-18')
data_2019['Age'] = (auction_date - pd.to_datetime(data_2019['dob'])).dt.days // 365

# Drop the DOB column
data_2019.drop('dob', axis=1, inplace=True)

# I'm just going to replace missing ages with the mean age (for now at least)
data_2019['Age'].fillna(data_2019['Age'].mean(), inplace=True)

print(data_2019['Age'].describe())
# Out:
# count    60.000000
# mean     25.392157
# std       4.337766
# min      17.000000
# 25%      22.750000
# 50%      25.392157
# 75%      28.000000
# max      35.000000
# Name: Age, dtype: float64

# %%
# Deal with missing values
data_2019.fillna(0, inplace=True)
data_2019.isnull().sum()
# Out:
# Role                   0
# Amount                 0
# Team                   0
# Year                   0
# Player Origin          0
#                       ..
# it20 2 bowling SR      0
# it20 2 overs bowled    0
# it20 2 wides           0
# it20 2 noballs         0
# Age                    0
# Length: 71, dtype: int64

# %%
# Drop the 'Team' column
data_2019.drop('Team', axis=1, inplace=True)

# Add dummy variables for 'Role' and 'Player Origin'
data_2019 = pd.get_dummies(data_2019, columns=['Role', 'Player Origin'])

# %% [markdown]
# ## 2020

# %%
auction_2020 = pd.read_csv('data/2020/ipl_auction_2020.csv')
auction_2020.set_index('Player', inplace=True)

# The following stats are calculates across two year intervals
# so, ipl_stats_1 contains stats calculated across the 2016 and 2017 seasons
# and ipl_stats_2 contains stats calculated across the 2014 and 2015 seasons
# For the it20 stats, the same follows, except the two year interval\
# ends the day before the auction of the 2018 ipl season

ipl_stats_1 = pd.read_csv('data/2020/ipl_stats_2018_2019.csv')
ipl_stats_2 = pd.read_csv('data/2020/ipl_stats_2008_2019.csv')
it20_stats_1 = pd.read_csv('data/2020/it20_stats_2018_2019.csv')
it20_stats_2 = pd.read_csv('data/2020/it20_stats_2005_2019.csv')

# Index by player name
ipl_stats_1.set_index('Player', inplace=True)
ipl_stats_2.set_index('Player', inplace=True)
it20_stats_1.set_index('Player', inplace=True)
it20_stats_2.set_index('Player', inplace=True)

# Drop played for country column if it exists
if 'Played For Country' in ipl_stats_1.columns:
    ipl_stats_1.drop('Played For Country', axis=1, inplace=True)
if 'Played For Country' in ipl_stats_2.columns:
    ipl_stats_2.drop('Played For Country', axis=1, inplace=True)
if 'Played For Country' in it20_stats_1.columns:
    it20_stats_1.drop('Played For Country', axis=1, inplace=True)
if 'Played For Country' in it20_stats_2.columns:
    it20_stats_2.drop('Played For Country', axis=1, inplace=True)

# Renaming the columns to make them unique
ipl_stats_1.columns = ['ipl 1 ' + col for col in ipl_stats_1.columns]
ipl_stats_2.columns = ['ipl 2 ' + col for col in ipl_stats_2.columns]
it20_stats_1.columns = ['it20 1 ' + col for col in it20_stats_1.columns]
it20_stats_2.columns = ['it20 2 ' + col for col in it20_stats_2.columns]

# Merging the dataframes
data_2020 = pd.concat([auction_2020, ipl_stats_1, ipl_stats_2, it20_stats_1, it20_stats_2], axis=1, sort=False)

data_2020.head()
# Out:
#                       Role    Amount                         Team    Year  \
# Player
# Aaron Finch        Batsman  44000000  Royal Challengers Bangalore  2020.0
# Abdul Samad    All-Rounder   2000000          Sunrisers Hyderabad  2020.0
# Akash Singh         Bowler   2000000             Rajasthan Royals  2020.0
# Alex Carey   Wicket Keeper  24000000               Delhi Capitals  2020.0
# Andrew Tye          Bowler  10000000             Rajasthan Royals  2020.0
#
#             Player Origin  Played For Country         dob  ipl 1 runs  \
# Player
# Aaron Finch      Overseas                 1.0  1986-11-17       134.0
# Abdul Samad        Indian                 0.0  2004-06-15         NaN
# Akash Singh        Indian                 0.0  1995-12-20         NaN
# Alex Carey       Overseas                 1.0  1991-08-27         NaN
# Andrew Tye       Overseas                 1.0  1986-12-12        32.0
#
#              ipl 1 balls  ipl 1 4s  ...  it20 2 times dismissed  \
# Player                              ...
# Aaron Finch        100.0       6.0  ...                    45.0
# Abdul Samad          NaN       NaN  ...                     NaN
# Akash Singh          NaN       NaN  ...                     NaN
# Alex Carey           NaN       NaN  ...                     8.0
# Andrew Tye          40.0       2.0  ...                     6.0
#
#              it20 2 balls bowled  it20 2 runs conceded  it20 2 wickets  \
# Player
# Aaron Finch                  6.0                   9.0             0.0
# Abdul Samad                  NaN                   NaN             NaN
# Akash Singh                  NaN                   NaN             NaN
# Alex Carey                   0.0                   0.0             0.0
# Andrew Tye                 576.0                 816.0            37.0
#
#              it20 2 economy  it20 2 bowling average  it20 2 bowling SR  \
# Player
# Aaron Finch            9.00                     NaN                NaN
# Abdul Samad             NaN                     NaN                NaN
# Akash Singh             NaN                     NaN                NaN
# Alex Carey              NaN                     NaN                NaN
# Andrew Tye             8.89                   22.05              15.57
#
#              it20 2 overs bowled  it20 2 wides  it20 2 noballs
# Player
# Aaron Finch                 1.00           0.0             0.0
# Abdul Samad                  NaN           NaN             NaN
# Akash Singh                  NaN           NaN             NaN
# Alex Carey                  0.00           0.0             0.0
# Andrew Tye                 91.83          21.0             4.0
#
# [5 rows x 71 columns]

# %%
# Now let's convert DOB to age at time of auction

auction_date = pd.to_datetime('2019-12-19')
data_2020['Age'] = (auction_date - pd.to_datetime(data_2020['dob'])).dt.days // 365

# Drop the DOB column
data_2020.drop('dob', axis=1, inplace=True)

# I'm just going to replace missing ages with the mean age (for now at least)
data_2020['Age'].fillna(data_2020['Age'].mean(), inplace=True)

print(data_2020['Age'].describe())
# Out:
# count    61.000000
# mean     26.537037
# std       5.445833
# min      15.000000
# 25%      23.000000
# 50%      26.537037
# 75%      30.000000
# max      48.000000
# Name: Age, dtype: float64

# %%
# Deal with missing values
data_2020.fillna(0, inplace=True)
data_2020.isnull().sum()
# Out:
# Role                   0
# Amount                 0
# Team                   0
# Year                   0
# Player Origin          0
#                       ..
# it20 2 bowling SR      0
# it20 2 overs bowled    0
# it20 2 wides           0
# it20 2 noballs         0
# Age                    0
# Length: 71, dtype: int64

# %%
# Drop the 'Team' column
data_2020.drop('Team', axis=1, inplace=True)

# Add dummy variables for 'Role' and 'Player Origin'
data_2020 = pd.get_dummies(data_2020, columns=['Role', 'Player Origin'])

# %% [markdown]
# ## Merging the years

# %%
# Add a column specifying the year of the auction and the minimum auction price
data_2018['Year'] = 2018
data_2018['Salary Cap (Crore)'] = 80
data_2019['Year'] = 2019
data_2019['Salary Cap (Crore)'] = 82
data_2020['Year'] = 2020
data_2020['Salary Cap (Crore)'] = 85

# %%
# Turn index into a column
data_2018.reset_index(inplace=True)
data_2019.reset_index(inplace=True)
data_2020.reset_index(inplace=True)

# Concatenate the two dataframes 
data = pd.concat([data_2018, data_2019, data_2020], axis=0, sort=False)

# Remove player column
data.drop('Player', axis=1, inplace=True)

print(f'{len(data_2018)} + {len(data_2019)} + {len(data_2020)}= {len(data)}')
data.head()
# Out:
# 169 + 60 + 61= 290
#      Amount  Year  Played For Country  ipl 1 runs  ipl 1 balls  ipl 1 4s  \
# 0  62000000  2018                 1.0       692.0        473.0      70.0
# 1   5500000  2018                 0.0         0.0          0.0       0.0
# 2   2000000  2018                 0.0        26.0         38.0       4.0
# 3  40000000  2018                 1.0       862.0        701.0      89.0
# 4   5000000  2018                 0.0         0.0          0.0       0.0
#
#    ipl 1 6s  ipl 1 batting SR  ipl 1 batting average  ipl 1 times dismissed  \
# 0      30.0            146.30                  32.95                   21.0
# 1       0.0              0.00                   0.00                    0.0
# 2       0.0             68.42                   5.20                    5.0
# 3      18.0            122.97                  33.15                   26.0
# 4       0.0              0.00                   0.00                    0.0
#
#    ...  it20 2 wides  it20 2 noballs        Age  Role_All-Rounder  \
# 0  ...           0.0             0.0  31.000000             False
# 1  ...           0.0             0.0  17.000000              True
# 2  ...           0.0             0.0  30.000000             False
# 3  ...           0.0             0.0  29.000000             False
# 4  ...           0.0             0.0  26.944056             False
#
#    Role_Batsman  Role_Bowler  Role_Wicket Keeper  Player Origin_Indian  \
# 0          True        False               False                 False
# 1         False        False               False                  True
# 2         False        False                True                  True
# 3          True        False               False                  True
# 4         False         True               False                 False
#
#    Player Origin_Overseas  Salary Cap (Crore)
# 0                    True                  80
# 1                   False                  80
# 2                   False                  80
# 3                   False                  80
# 4                    True                  80
#
# [5 rows x 75 columns]

# %% [markdown]
# # Neural Network

# %%
# Split into train and test
data = data.sample(frac=1, random_state=42).reset_index(drop=True)
x_train, x_test, y_train, y_test = train_test_split(data.drop('Amount', axis=1), data['Amount'], test_size=0.3, random_state=42)

# Converting values to numpy floats
x_train = x_train.values.astype("float32")
x_test = x_test.values.astype("float32")
y_train = y_train.values.astype("float32")
y_test = y_test.values.astype("float32")

# Reserve 10% of the training data for validation
x_val = x_train[-(int(0.1 * len(x_train))):]
y_val = y_train[-(int(0.1 * len(y_train))):]
x_train = x_train[:-(int(0.1 * len(x_train)))]
y_train = y_train[:-(int(0.1 * len(y_train)))]

# Create the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(25, activation=tf.nn.relu, input_shape=(x_train.shape[1:])),
    tf.keras.layers.Dense(20, activation=tf.nn.relu, input_shape=(x_train.shape[1:])),
    tf.keras.layers.Dense(20, activation=tf.nn.relu, input_shape=(x_train.shape[1:])),
    tf.keras.layers.Dense(5, activation=tf.nn.relu, input_shape=(x_train.shape[1:])),
    tf.keras.layers.Dense(10, activation=tf.nn.relu, input_shape=(x_train.shape[1:])),
    tf.keras.layers.Dense(10, activation=tf.nn.relu, input_shape=(x_train.shape[1:])),
    tf.keras.layers.Dense(10, activation=tf.nn.relu, input_shape=(x_train.shape[1:])),
    tf.keras.layers.Dense(1) # ouput
])

# I use a callback to stop training early when the validation loss stops decreasing
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15)

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.02), # Using the Adam optimizer
    loss=tf.keras.losses.MeanAbsolutePercentageError(), # Mean Absolute Percentage Error
    metrics=[tf.keras.metrics.MeanAbsoluteError()]
)

print("Fit model on training data")
history = model.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=400,
    validation_data=(x_val, y_val),
    callbacks=[callback]
)
# Out:
# Fit model on training data
# Epoch 1/400
# 23/23 [==============================] - 1s 16ms/step - loss: 99.8410 - mean_absolute_error: 23031326.0000 - val_loss: 97.6126 - val_mean_absolute_error: 25531076.0000
# Epoch 2/400
# 23/23 [==============================] - 0s 4ms/step - loss: 71.8057 - mean_absolute_error: 20437754.0000 - val_loss: 63.2854 - val_mean_absolute_error: 22202088.0000
# Epoch 3/400
# 23/23 [==============================] - 0s 4ms/step - loss: 55.0023 - mean_absolute_error: 19227092.0000 - val_loss: 62.5318 - val_mean_absolute_error: 20535252.0000
# Epoch 4/400
# 23/23 [==============================] - 0s 4ms/step - loss: 56.1613 - mean_absolute_error: 18728222.0000 - val_loss: 62.5822 - val_mean_absolute_error: 20317610.0000
# Epoch 5/400
# 23/23 [==============================] - 0s 3ms/step - loss: 55.5858 - mean_absolute_error: 18923556.0000 - val_loss: 59.1824 - val_mean_absolute_error: 21435982.0000
# Epoch 6/400
# 23/23 [==============================] - 0s 4ms/step - loss: 53.7250 - mean_absolute_error: 18857958.0000 - val_loss: 59.7642 - val_mean_absolute_error: 20676000.0000
# Epoch 7/400
# 23/23 [==============================] - 0s 4ms/step - loss: 57.4569 - mean_absolute_error: 18901610.0000 - val_loss: 61.2814 - val_mean_absolute_error: 20452844.0000
# Epoch 8/400
# 23/23 [==============================] - 0s 3ms/step - loss: 56.5240 - mean_absolute_error: 18760714.0000 - val_loss: 58.7092 - val_mean_absolute_error: 20915360.0000
# Epoch 9/400
# 23/23 [==============================] - 0s 4ms/step - loss: 52.9981 - mean_absolute_error: 18776736.0000 - val_loss: 56.4577 - val_mean_absolute_error: 21047334.0000
# Epoch 10/400
# 23/23 [==============================] - 0s 4ms/step - loss: 53.1274 - mean_absolute_error: 18580136.0000 - val_loss: 57.6055 - val_mean_absolute_error: 20977866.0000
# Epoch 11/400
# 23/23 [==============================] - 0s 3ms/step - loss: 53.7484 - mean_absolute_error: 18627294.0000 - val_loss: 60.1441 - val_mean_absolute_error: 20365332.0000
# Epoch 12/400
# 23/23 [==============================] - 0s 3ms/step - loss: 58.6880 - mean_absolute_error: 18468758.0000 - val_loss: 57.4547 - val_mean_absolute_error: 20799386.0000
# Epoch 13/400
# 23/23 [==============================] - 0s 3ms/step - loss: 54.1997 - mean_absolute_error: 18068956.0000 - val_loss: 57.6352 - val_mean_absolute_error: 20580662.0000
# Epoch 14/400
# 23/23 [==============================] - 0s 3ms/step - loss: 51.8229 - mean_absolute_error: 18292748.0000 - val_loss: 56.8743 - val_mean_absolute_error: 21112838.0000
# Epoch 15/400
# 23/23 [==============================] - 0s 3ms/step - loss: 54.0708 - mean_absolute_error: 18500736.0000 - val_loss: 56.5153 - val_mean_absolute_error: 20702388.0000
# Epoch 16/400
# 23/23 [==============================] - 0s 3ms/step - loss: 53.5786 - mean_absolute_error: 18367644.0000 - val_loss: 57.5349 - val_mean_absolute_error: 20329856.0000
# Epoch 17/400
# 23/23 [==============================] - 0s 3ms/step - loss: 51.9228 - mean_absolute_error: 18206420.0000 - val_loss: 57.8045 - val_mean_absolute_error: 20578120.0000
# Epoch 18/400
# 23/23 [==============================] - 0s 4ms/step - loss: 55.0842 - mean_absolute_error: 17762640.0000 - val_loss: 57.5931 - val_mean_absolute_error: 20623632.0000
# Epoch 19/400
# 23/23 [==============================] - 0s 3ms/step - loss: 57.1932 - mean_absolute_error: 18765790.0000 - val_loss: 58.6289 - val_mean_absolute_error: 21289076.0000
# Epoch 20/400
# 23/23 [==============================] - 0s 3ms/step - loss: 55.6684 - mean_absolute_error: 17902408.0000 - val_loss: 61.6093 - val_mean_absolute_error: 21600100.0000
# Epoch 21/400
# 23/23 [==============================] - 0s 3ms/step - loss: 52.7469 - mean_absolute_error: 18190268.0000 - val_loss: 56.9683 - val_mean_absolute_error: 20695792.0000
# Epoch 22/400
# 23/23 [==============================] - 0s 3ms/step - loss: 49.8097 - mean_absolute_error: 18075748.0000 - val_loss: 57.1693 - val_mean_absolute_error: 20771448.0000
# Epoch 23/400
# 23/23 [==============================] - 0s 3ms/step - loss: 50.7128 - mean_absolute_error: 17882890.0000 - val_loss: 57.8402 - val_mean_absolute_error: 20352164.0000
# Epoch 24/400
# 23/23 [==============================] - 0s 3ms/step - loss: 51.5289 - mean_absolute_error: 17774464.0000 - val_loss: 58.0702 - val_mean_absolute_error: 20268300.0000

# %%
print("Evaluate on test data")
results = model.evaluate(x_test, y_test, batch_size=8)
print("test loss, test mae:", results)

# Generate predictions
print("Generate predictions for 3 samples")
predictions = model.predict(x_test[:3])
print("predictions shape:", predictions.shape)
# Out:
# Evaluate on test data
# 11/11 [==============================] - 0s 1ms/step - loss: 62.6042 - mean_absolute_error: 17995948.0000
# test loss, test mae: [62.60423278808594, 17995948.0]
# Generate predictions for 3 samples
# 1/1 [==============================] - 0s 156ms/step
# predictions shape: (3, 1)

# %%
y_pred = model.predict(x_test)

# Plot the predictions
plt.figure(figsize=(10, 6))
sns.scatterplot(data=y_test, label='Actual', color='blue')
sns.lineplot(data=y_pred, label='Predicted', color='red')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='blue')
plt.xlim(0, 1e8)
plt.ylim(0, 1e8)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Price')
plt.show()

# Distribution of the actual and predicted values
plt.figure(figsize=(10, 6))
sns.histplot(y_test, color='blue', label='Actual', kde=True)
sns.histplot(y_pred, color='red', label='Predicted', kde=True)
plt.title('Distribution of Actual and Predicted Values')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# 3/3 [==============================] - 0s 3ms/step

# %% [markdown]
# # 2024 Predictions
#
# This section of the notebook contains code used to predict prices for players in the 2024 auction list. These prices are then used in the ipl teampicker program.

# %% [markdown]
# ## Preparing the data

# %%
auction_2024 = pd.read_csv('data/2024/ipl_auction_2024.csv')
auction_2024.set_index('Player', inplace=True)

# Load in the stats
ipl_stats_1 = pd.read_csv('data/2024/ipl_stats_2022_2023.csv')
ipl_stats_2 = pd.read_csv('data/2024/ipl_stats_2008_2023.csv')
it20_stats_1 = pd.read_csv('data/2024/it20_stats_2022_2023.csv')
it20_stats_2 = pd.read_csv('data/2024/it20_stats_2005_2023.csv')

# Index by player name
ipl_stats_1.set_index('Player', inplace=True)
ipl_stats_2.set_index('Player', inplace=True)
it20_stats_1.set_index('Player', inplace=True)
it20_stats_2.set_index('Player', inplace=True)

# Drop played for country column if it exists
if 'Played For Country' in ipl_stats_1.columns:
    ipl_stats_1.drop('Played For Country', axis=1, inplace=True)
if 'Played For Country' in ipl_stats_2.columns:
    ipl_stats_2.drop('Played For Country', axis=1, inplace=True)
if 'Played For Country' in it20_stats_1.columns:
    it20_stats_1.drop('Played For Country', axis=1, inplace=True)
if 'Played For Country' in it20_stats_2.columns:
    it20_stats_2.drop('Played For Country', axis=1, inplace=True)

# Renaming the columns to make them unique
ipl_stats_1.columns = ['ipl 1 ' + col for col in ipl_stats_1.columns]
ipl_stats_2.columns = ['ipl 2 ' + col for col in ipl_stats_2.columns]
it20_stats_1.columns = ['it20 1 ' + col for col in it20_stats_1.columns]
it20_stats_2.columns = ['it20 2 ' + col for col in it20_stats_2.columns]

# Merging the dataframes
data_2024 = pd.concat([auction_2024, ipl_stats_1, ipl_stats_2, it20_stats_1, it20_stats_2], axis=1, sort=False)

print(data_2024.columns)
data_2024.head()
# Out:
# Index(['Player Origin', 'Role', 'Played For Country', 'dob', 'ipl 1 runs',
#        'ipl 1 balls', 'ipl 1 4s', 'ipl 1 6s', 'ipl 1 batting SR',
#        'ipl 1 batting average', 'ipl 1 times dismissed', 'ipl 1 balls bowled',
#        'ipl 1 runs conceded', 'ipl 1 wickets', 'ipl 1 economy',
#        'ipl 1 bowling average', 'ipl 1 bowling SR', 'ipl 1 overs bowled',
#        'ipl 1 wides', 'ipl 1 noballs', 'ipl 2 runs', 'ipl 2 balls', 'ipl 2 4s',
#        'ipl 2 6s', 'ipl 2 batting SR', 'ipl 2 batting average',
#        'ipl 2 times dismissed', 'ipl 2 balls bowled', 'ipl 2 runs conceded',
#        'ipl 2 wickets', 'ipl 2 economy', 'ipl 2 bowling average',
#        'ipl 2 bowling SR', 'ipl 2 overs bowled', 'ipl 2 wides',
#        'ipl 2 noballs', 'it20 1 runs', 'it20 1 balls', 'it20 1 4s',
#        'it20 1 6s', 'it20 1 batting SR', 'it20 1 batting average',
#        'it20 1 times dismissed', 'it20 1 balls bowled', 'it20 1 runs conceded',
#        'it20 1 wickets', 'it20 1 economy', 'it20 1 bowling average',
#        'it20 1 bowling SR', 'it20 1 overs bowled', 'it20 1 wides',
#        'it20 1 noballs', 'it20 2 runs', 'it20 2 balls', 'it20 2 4s',
#        'it20 2 6s', 'it20 2 batting SR', 'it20 2 batting average',
#        'it20 2 times dismissed', 'it20 2 balls bowled', 'it20 2 runs conceded',
#        'it20 2 wickets', 'it20 2 economy', 'it20 2 bowling average',
#        'it20 2 bowling SR', 'it20 2 overs bowled', 'it20 2 wides',
#        'it20 2 noballs'],
#       dtype='object')
#                      Player Origin         Role  Played For Country  \
# Player
# Abid Mushtaq                Indian  All-Rounder                 0.0
# Akash Singh                 Indian       Bowler                 0.0
# Angkrish Raghuvanshi        Indian       Batter                 0.0
# Anshul Kamboj               Indian  All-Rounder                 0.0
# Arshin Kulkarni             Indian  All-Rounder                 0.0
#
#                              dob  ipl 1 runs  ipl 1 balls  ipl 1 4s  ipl 1 6s  \
# Player
# Abid Mushtaq          1997-01-17         NaN          NaN       NaN       NaN
# Akash Singh           1995-12-20         0.0          0.0       0.0       0.0
# Angkrish Raghuvanshi  2005-06-05         NaN          NaN       NaN       NaN
# Anshul Kamboj         2000-12-06         NaN          NaN       NaN       NaN
# Arshin Kulkarni       2005-02-15         NaN          NaN       NaN       NaN
#
#                       ipl 1 batting SR  ipl 1 batting average  ...  \
# Player                                                         ...
# Abid Mushtaq                       NaN                    NaN  ...
# Akash Singh                        NaN                    0.0  ...
# Angkrish Raghuvanshi               NaN                    NaN  ...
# Anshul Kamboj                      NaN                    NaN  ...
# Arshin Kulkarni                    NaN                    NaN  ...
#
#                       it20 2 times dismissed  it20 2 balls bowled  \
# Player
# Abid Mushtaq                             NaN                  NaN
# Akash Singh                              NaN                  NaN
# Angkrish Raghuvanshi                     NaN                  NaN
# Anshul Kamboj                            NaN                  NaN
# Arshin Kulkarni                          NaN                  NaN
#
#                       it20 2 runs conceded  it20 2 wickets  it20 2 economy  \
# Player
# Abid Mushtaq                           NaN             NaN             NaN
# Akash Singh                            NaN             NaN             NaN
# Angkrish Raghuvanshi                   NaN             NaN             NaN
# Anshul Kamboj                          NaN             NaN             NaN
# Arshin Kulkarni                        NaN             NaN             NaN
#
#                       it20 2 bowling average  it20 2 bowling SR  \
# Player
# Abid Mushtaq                             NaN                NaN
# Akash Singh                              NaN                NaN
# Angkrish Raghuvanshi                     NaN                NaN
# Anshul Kamboj                            NaN                NaN
# Arshin Kulkarni                          NaN                NaN
#
#                       it20 2 overs bowled  it20 2 wides  it20 2 noballs
# Player
# Abid Mushtaq                          NaN           NaN             NaN
# Akash Singh                           NaN           NaN             NaN
# Angkrish Raghuvanshi                  NaN           NaN             NaN
# Anshul Kamboj                         NaN           NaN             NaN
# Arshin Kulkarni                       NaN           NaN             NaN
#
# [5 rows x 68 columns]

# %%
# Now let's convert DOB to age at time of auction

auction_date = pd.to_datetime('2023-12-19')
data_2024['Age'] = (auction_date - pd.to_datetime(data_2024['dob'])).dt.days // 365

# Drop the DOB column
data_2024.drop('dob', axis=1, inplace=True)

# I'm just going to replace missing ages with the mean age (for now at least)
data_2024['Age'].fillna(data_2024['Age'].mean(), inplace=True)

print(data_2024['Age'].describe())
# Out:
# count    332.000000
# mean      27.225000
# std        4.351207
# min       16.000000
# 25%       25.000000
# 50%       27.225000
# 75%       30.000000
# max       43.000000
# Name: Age, dtype: float64

# %%
# Deal with missing values
data_2024.fillna(0, inplace=True)
data_2024.isnull().sum()
# Out:
# Player Origin          0
# Role                   0
# Played For Country     0
# ipl 1 runs             0
# ipl 1 balls            0
#                       ..
# it20 2 bowling SR      0
# it20 2 overs bowled    0
# it20 2 wides           0
# it20 2 noballs         0
# Age                    0
# Length: 68, dtype: int64

# %%
print(data_2024.columns)
# Out:
# Index(['Year', 'Played For Country', 'ipl 1 runs', 'ipl 1 balls', 'ipl 1 4s',
#        'ipl 1 6s', 'ipl 1 batting SR', 'ipl 1 batting average',
#        'ipl 1 times dismissed', 'ipl 1 balls bowled', 'ipl 1 runs conceded',
#        'ipl 1 wickets', 'ipl 1 economy', 'ipl 1 bowling average',
#        'ipl 1 bowling SR', 'ipl 1 overs bowled', 'ipl 1 wides',
#        'ipl 1 noballs', 'ipl 2 runs', 'ipl 2 balls', 'ipl 2 4s', 'ipl 2 6s',
#        'ipl 2 batting SR', 'ipl 2 batting average', 'ipl 2 times dismissed',
#        'ipl 2 balls bowled', 'ipl 2 runs conceded', 'ipl 2 wickets',
#        'ipl 2 economy', 'ipl 2 bowling average', 'ipl 2 bowling SR',
#        'ipl 2 overs bowled', 'ipl 2 wides', 'ipl 2 noballs', 'it20 1 runs',
#        'it20 1 balls', 'it20 1 4s', 'it20 1 6s', 'it20 1 batting SR',
#        'it20 1 batting average', 'it20 1 times dismissed',
#        'it20 1 balls bowled', 'it20 1 runs conceded', 'it20 1 wickets',
#        'it20 1 economy', 'it20 1 bowling average', 'it20 1 bowling SR',
#        'it20 1 overs bowled', 'it20 1 wides', 'it20 1 noballs', 'it20 2 runs',
#        'it20 2 balls', 'it20 2 4s', 'it20 2 6s', 'it20 2 batting SR',
#        'it20 2 batting average', 'it20 2 times dismissed',
#        'it20 2 balls bowled', 'it20 2 runs conceded', 'it20 2 wickets',
#        'it20 2 economy', 'it20 2 bowling average', 'it20 2 bowling SR',
#        'it20 2 overs bowled', 'it20 2 wides', 'it20 2 noballs', 'Age',
#        'Role_All-Rounder', 'Role_Batter', 'Role_Bowler', 'Role_Wicket-Keeper',
#        'Player Origin_Indian', 'Player Origin_Overseas', 'Salary Cap (Crore)'],
#       dtype='object')

# %%
print(data_2024)
# Out:
#                       Year  Played For Country  ipl 1 runs  ipl 1 balls  \
# Player
# Abid Mushtaq          2024                 0.0         0.0          0.0
# Akash Singh           2024                 0.0         0.0          0.0
# Angkrish Raghuvanshi  2024                 0.0         0.0          0.0
# Anshul Kamboj         2024                 0.0         0.0          0.0
# Arshin Kulkarni       2024                 0.0         0.0          0.0
# ...                    ...                 ...         ...          ...
# Jagadeesha Suchith    2024                 0.0         2.0          8.0
# B. Surya              2024                 0.0         0.0          0.0
# Pankaj Yadav          2024                 0.0         0.0          0.0
# Sahil Dhiwan          2024                 0.0         0.0          0.0
# Kaushal Tambe         2024                 0.0         0.0          0.0
#
#                       ipl 1 4s  ipl 1 6s  ipl 1 batting SR  \
# Player
# Abid Mushtaq               0.0       0.0               0.0
# Akash Singh                0.0       0.0               0.0
# Angkrish Raghuvanshi       0.0       0.0               0.0
# Anshul Kamboj              0.0       0.0               0.0
# Arshin Kulkarni            0.0       0.0               0.0
# ...                        ...       ...               ...
# Jagadeesha Suchith         0.0       0.0              25.0
# B. Surya                   0.0       0.0               0.0
# Pankaj Yadav               0.0       0.0               0.0
# Sahil Dhiwan               0.0       0.0               0.0
# Kaushal Tambe              0.0       0.0               0.0
#
#                       ipl 1 batting average  ipl 1 times dismissed  \
# Player
# Abid Mushtaq                            0.0                    0.0
# Akash Singh                             0.0                    0.0
# Angkrish Raghuvanshi                    0.0                    0.0
# Anshul Kamboj                           0.0                    0.0
# Arshin Kulkarni                         0.0                    0.0
# ...                                     ...                    ...
# Jagadeesha Suchith                      1.0                    2.0
# B. Surya                                0.0                    0.0
# Pankaj Yadav                            0.0                    0.0
# Sahil Dhiwan                            0.0                    0.0
# Kaushal Tambe                           0.0                    0.0
#
#                       ipl 1 balls bowled  ...  it20 2 wides  it20 2 noballs  \
# Player                                    ...
# Abid Mushtaq                         0.0  ...           0.0             0.0
# Akash Singh                        117.0  ...           0.0             0.0
# Angkrish Raghuvanshi                 0.0  ...           0.0             0.0
# Anshul Kamboj                        0.0  ...           0.0             0.0
# Arshin Kulkarni                      0.0  ...           0.0             0.0
# ...                                  ...  ...           ...             ...
# Jagadeesha Suchith                 115.0  ...           0.0             0.0
# B. Surya                             0.0  ...           0.0             0.0
# Pankaj Yadav                         0.0  ...           0.0             0.0
# Sahil Dhiwan                         0.0  ...           0.0             0.0
# Kaushal Tambe                        0.0  ...           0.0             0.0
#
#                          Age  Role_All-Rounder  Role_Batter  Role_Bowler  \
# Player
# Abid Mushtaq          26.000              True        False        False
# Akash Singh           28.000             False        False         True
# Angkrish Raghuvanshi  18.000             False         True        False
# Anshul Kamboj         23.000              True        False        False
# Arshin Kulkarni       18.000              True        False        False
# ...                      ...               ...          ...          ...
# Jagadeesha Suchith    29.000             False        False         True
# B. Surya              27.225             False        False         True
# Pankaj Yadav          27.000             False        False         True
# Sahil Dhiwan          26.000              True        False        False
# Kaushal Tambe         21.000              True        False        False
#
#                       Role_Wicket-Keeper  Player Origin_Indian  \
# Player
# Abid Mushtaq                       False                  True
# Akash Singh                        False                  True
# Angkrish Raghuvanshi               False                  True
# Anshul Kamboj                      False                  True
# Arshin Kulkarni                    False                  True
# ...                                  ...                   ...
# Jagadeesha Suchith                 False                  True
# B. Surya                           False                  True
# Pankaj Yadav                       False                  True
# Sahil Dhiwan                       False                  True
# Kaushal Tambe                      False                  True
#
#                       Player Origin_Overseas  Salary Cap (Crore)
# Player
# Abid Mushtaq                           False                 100
# Akash Singh                            False                 100
# Angkrish Raghuvanshi                   False                 100
# Anshul Kamboj                          False                 100
# Arshin Kulkarni                        False                 100
# ...                                      ...                 ...
# Jagadeesha Suchith                     False                 100
# B. Surya                               False                 100
# Pankaj Yadav                           False                 100
# Sahil Dhiwan                           False                 100
# Kaushal Tambe                          False                 100
#
# [332 rows x 74 columns]

# %%
# Convert to numpy arrays
X = data_2024.values.astype("float32")

# Generate predictions
predictions = model.predict(X)
predictions = pd.Series(predictions.flatten())

# Plot the predictions
plt.figure(figsize=(10, 6))
sns.histplot(predictions, color='blue', kde=True)
plt.title('Predicted Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()
# Out:
# 11/11 [==============================] - 0s 1ms/step

# %%
# Get indexes as a series
players = data_2024.index.to_series()
print(players)
# Out:
# Player
# Abid Mushtaq                    Abid Mushtaq
# Akash Singh                      Akash Singh
# Angkrish Raghuvanshi    Angkrish Raghuvanshi
# Anshul Kamboj                  Anshul Kamboj
# Arshin Kulkarni              Arshin Kulkarni
#                                 ...
# Jagadeesha Suchith        Jagadeesha Suchith
# B. Surya                            B. Surya
# Pankaj Yadav                    Pankaj Yadav
# Sahil Dhiwan                    Sahil Dhiwan
# Kaushal Tambe                  Kaushal Tambe
# Name: Player, Length: 332, dtype: object

# %%
predicted_prices = pd.DataFrame()
predicted_prices['Player'] = data_2024.index.to_list()
predicted_prices['Amount'] = predictions
predicted_prices.head()
# Out:
#                  Player      Amount
# 0          Abid Mushtaq  2108533.00
# 1           Akash Singh  3987720.50
# 2  Angkrish Raghuvanshi  2105171.50
# 3         Anshul Kamboj  2105053.25
# 4       Arshin Kulkarni  2099252.50

# %%
# Save to csv
predicted_prices.to_csv('data/predicted_prices_2024.csv', index=False)

# %%
auction_pool_2024 = pd.read_csv('../ipl-teampicker/2024_auction_pool_mock.csv')
auction_pool_2024['Price'] = predictions
# Save to csv
auction_pool_2024.to_csv('../ipl-teampicker/2024_auction_pool_with_prices.csv', index=False)
