# %% [markdown]
# # jupyter notebook to calculate the optimal combination of weights for pm

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lenovo\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)

# %%
import pandas as pd
from scipy.optimize import nnls
from sklearn.metrics import mean_squared_error

# %%
ranking = pd.read_csv('actual_rankings.csv')
#has 99 if the team wasnt playing that year cause in 2022 there was an expansion
#should replace with 0
ranking = ranking.replace(99, 0)
ranking.head()
# Out:
#                    Team  2008 Actual Rank  2009 Actual Rank  2010 Actual Rank  \
# 0  Kolkata Night Riders                 6                 8                 6
# 1        Mumbai Indians                 5                 7                 1
# 2       Kings XI Punjab                 2                 5                 8
# 3    Sunrisers Hyderbad                 8                 4                 2
# 4      Rajasthan Royals                 1                 6                 7
#
#    2011 Actual Rank  2012 Actual Rank  2013 Actual Rank  2014 Actual Rank  \
# 0                 4                 2                 7                 2
# 1                 3                 3                 2                 4
# 2                 5                 6                 6                 1
# 3                 7                 8                 4                 6
# 4                 6                 7                 3                 5
#
#    2015 Actual Rank  2016 Actual Rank  2017 Actual Rank  2018 Actual Rank  \
# 0                 5                 4                 4                 3
# 1                 2                 5                 1                 5
# 2                 8                 8                 5                 7
# 3                 6                 3                 3                 1
# 4                 4                 0                 0                 4
#
#    2019 Actual Rank  2020 Actual Rank  2021 Actual Rank  2022 Actual Rank  \
# 0                 5                 5                 4                 7
# 1                 1                 1                 5                10
# 2                 6                 6                 6                 6
# 3                 4                 3                 8                 8
# 4                 7                 8                 7                 2
#
#    2023 Actual Rank
# 0                 7
# 1                 4
# 2                 8
# 3                10
# 4                 5

# %%
teams = ranking['Team'].tolist()
print(teams)
# Out:
# ['Kolkata Night Riders', 'Mumbai Indians', 'Kings XI Punjab', 'Sunrisers Hyderbad', 'Rajasthan Royals', 'Delhi Capitals', 'Royal Challengers Bangalore', 'Chennai Super Kings', 'Gujarat Titans', 'Lucknow Super Giants', 'Kochi Tuskers Kerala']

# %%
predicted_rankings = pd.read_csv('predicted_rankings.csv')
if 'Unnamed: 0' in predicted_rankings.columns:
    predicted_rankings = predicted_rankings.drop(columns=['Unnamed: 0'])
predicted_rankings.head()

#now here have to insert rows for each team that wasnt there that year and give 0 aswell
#the names of these teams are the Lucknow Super Giants and Gujarat Titans, so insert rows for both team with rank 0 for each year
# Out:
#                      team_name  rank_pm1  rank_pm2  rank_pm3  year
# 0          Chennai Super Kings         2         4         2  2008
# 1             Rajasthan Royals         4         2         5  2008
# 2  Royal Challengers Bangalore         8         8         6  2008
# 3        Kolkata Knight Riders         7         7         7  2008
# 4               Delhi Capitals         5         3         4  2008

# %%
years = predicted_rankings['year'].unique()

new_teams = ["Lucknow Super Giants", "Gujarat Titans"]

new_rows = []

old_teams = ["Deccan Chargers"]

for year in range(2008,2022):
    for team in new_teams:
        new_rows.append({
            'team_name': team,
            'rank_pm1': 0,
            'rank_pm2': 0,
            'rank_pm3': 0,
            'year': year
        })

new_teams_df = pd.DataFrame(new_rows)

predicted_rankings = pd.concat([predicted_rankings, new_teams_df], ignore_index=True)

predicted_rankings.head()
# Out:
#                      team_name  rank_pm1  rank_pm2  rank_pm3  year
# 0          Chennai Super Kings         2         4         2  2008
# 1             Rajasthan Royals         4         2         5  2008
# 2  Royal Challengers Bangalore         8         8         6  2008
# 3        Kolkata Knight Riders         7         7         7  2008
# 4               Delhi Capitals         5         3         4  2008

# %%
years = predicted_rankings['year'].unique()
    
disqualified_teams = ["Rajasthan Royals", "Chennai Super Kings"]
    
team_gt = "Gujarat Titans"
team_lsg = "Lucknow Super Giants"
team_ktk = "Kochi Tuskers Kerala"

"""for year in range(2008,2022):
    for team in new_teams:
        new_rows.append({
            'team_name': team,
            'rank_pm1': 0,
            'rank_pm2': 0,
            'rank_pm3': 0,
            'year': year
        })"""


new_rows = []
#Adding the disqualified teams only for the years they were nt disqualified
for year in range(2008, 2015):
    for team in disqualified_teams:
        new_rows.append({
            'team_name': team,
            'rank_pm1': 0,
            'rank_pm2': 0,
            'rank_pm3': 0,
            'year': year
        })
            
for year in range(2018, 2023):
    for team in disqualified_teams:
        new_rows.append({
        'team_name': team,
        'rank_pm1': 0,
        'rank_pm2': 0,
        'rank_pm3': 0,
        'year': year
    })



#Adding Lucknow Super Giants and Gujarat Titans for the years they were active
for year in range(2016, 2017):
        new_rows.append({
        'team_name': team_gt, 
        'rank_pm1': 0,
        'rank_pm2': 0,
        'rank_pm3': 0,
        'year': year
    })
        new_rows.append({
        'team_name': team_lsg,
        'rank_pm1': 0,
        'rank_pm2': 0,
        'rank_pm3': 0,
        'year': year
    })

for year in range(2022,2023):
        new_rows.append({
        'team_name': team_gt,
        'rank_pm1': 0,
        'rank_pm2': 0,
        'rank_pm3': 0,
        'year': year
    })

        new_rows.append({
        'team_name': team_lsg,
        'rank_pm1': 0,
        'rank_pm2': 0,
        'rank_pm3': 0,
        'year': year
    })

for year in range(2011,2013):
        new_rows.append({
        'team_name': team_lsg,
        'rank_pm1': 0,
        'rank_pm2': 0,
        'rank_pm3': 0,
        'year': year
    })



#Adding Kochi Tuskers Kerala for the year they were active
new_rows.append({
    'team_name': team_ktk,
    'rank_pm1': 0,
    'rank_pm2': 0,
    'rank_pm3': 0,
    'year': 2011
})

new_teams_df = pd.DataFrame(new_rows)

predicted_rankings = pd.concat([predicted_rankings, new_teams_df], ignore_index=True)

predicted_rankings.head()
# Out:
#                      team_name  rank_pm1  rank_pm2  rank_pm3  year
# 0          Chennai Super Kings         2         4         2  2008
# 1             Rajasthan Royals         4         2         5  2008
# 2  Royal Challengers Bangalore         8         8         6  2008
# 3        Kolkata Knight Riders         7         7         7  2008
# 4               Delhi Capitals         5         3         4  2008

# %% [markdown]
# The reason I give zero to the ranking for the expansion teams is because I gave them actual rank 0 aswell. So whatever the weights, the loss will always be zero so they wont influence the LR but still give everything matching dimensions.

# %%
# Reshape actual ranking data for merging
ranking_melted = ranking.melt(id_vars=['Team'], 
                              value_vars=['2008 Actual Rank', '2009 Actual Rank', '2010 Actual Rank', '2011 Actual Rank', '2012 Actual Rank', '2013 Actual Rank', '2014 Actual Rank', '2015 Actual Rank', '2016 Actual Rank', '2017 Actual Rank', '2018 Actual Rank', '2019 Actual Rank', '2020 Actual Rank', '2021 Actual Rank', '2022 Actual Rank', '2023 Actual Rank'],
                              var_name='Year', value_name='Actual Rank')

# Extract the year from the 'Year' column
ranking_melted['Year'] = ranking_melted['Year'].str.extract('(\d+)').astype(int)

# Merge metrics rankings and actual rankings
data = pd.merge(predicted_rankings, ranking_melted, left_on=['team_name', 'year'], right_on=['Team', 'Year'])

# Drop unnecessary columns
data = data.drop(columns=['Team', 'year'])

print(data)
# Out:
#                        team_name  rank_pm1  rank_pm2  rank_pm3  Year  \
# 0            Chennai Super Kings         2         4         2  2008
# 1               Rajasthan Royals         4         2         5  2008
# 2    Royal Challengers Bangalore         8         8         6  2008
# 3                 Delhi Capitals         5         3         4  2008
# 4                Kings XI Punjab         1         1         1  2008
# ..                           ...       ...       ...       ...   ...
# 141               Gujarat Titans         0         0         0  2022
# 142         Lucknow Super Giants         0         0         0  2022
# 143         Lucknow Super Giants         0         0         0  2011
# 144         Lucknow Super Giants         0         0         0  2012
# 145         Kochi Tuskers Kerala         0         0         0  2011
#
#      Actual Rank
# 0              3
# 1              1
# 2              7
# 3              4
# 4              2
# ..           ...
# 141            1
# 142            3
# 143            9
# 144            9
# 145            8
#
# [146 rows x 6 columns]
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15720\2492647760.py:7: SyntaxWarning: invalid escape sequence '\d'
#   ranking_melted['Year'] = ranking_melted['Year'].str.extract('(\d+)').astype(int)

# %%
X = data[['rank_pm1', 'rank_pm2', 'rank_pm3']]
y = data['Actual Rank']

# Use Non-Negative Least Squares (NNLS) to fit the model
weights, residual = nnls(X, y)

print("Weights: ", weights)
print("Residual: ", residual)

# Use the model to predict rankings
predicted_rankings = X.dot(weights)

# Evaluate the model
mse = mean_squared_error(y, predicted_rankings)
print("Mean Squared Error: ", mse)

# Print the actual and predicted rankings
result = data[['Year', 'Actual Rank', 'team_name']].copy()
result['Predicted Rank'] = predicted_rankings
print(result)
# Out:
# Weights:  [0.         0.54050713 0.17264483]
# Residual:  40.486165420809385
# Mean Squared Error:  14.009654619496935
#      Year  Actual Rank                    team_name  Predicted Rank
# 0    2008            3          Chennai Super Kings        2.875181
# 1    2008            1             Rajasthan Royals        1.966811
# 2    2008            7  Royal Challengers Bangalore        2.852608
# 3    2008            2              Kings XI Punjab        2.116883
# 4    2008            5               Mumbai Indians        4.992064
# ..    ...          ...                          ...             ...
# 112  2022            1               Gujarat Titans        0.000000
# 113  2022            3         Lucknow Super Giants        0.000000
# 114  2011            9         Lucknow Super Giants        0.000000
# 115  2012            9         Lucknow Super Giants        0.000000
# 116  2011            8         Kochi Tuskers Kerala        0.000000
#
# [117 rows x 4 columns]
